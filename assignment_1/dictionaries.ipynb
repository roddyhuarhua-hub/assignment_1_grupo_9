# %% [markdown]
# # Part 3 – Dictionaries

# %% [markdown]
# ## Print of the dictionarie

# %%
population = {
    "Lima": 10092000,
    "Arequipa": 1008000,
    "Trujillo": 919000
}
population
# Out:
# {'Lima': 10092000, 'Arequipa': 1008000, 'Trujillo': 919000}

# %% [markdown]
# ## Keys of the dictionarie

# %%
population.keys()
# Out:
# dict_keys(['Lima', 'Arequipa', 'Trujillo'])

# %% [markdown]
# ## Population of "Lima"

# %%
population.get("Lima")
# Out:
# 10092000

# %% [markdown]
# ## Add "Cusco": 428000

# %%
population["Cusco"]=428000
population
# Out:
# {'Lima': 10092000, 'Arequipa': 1008000, 'Trujillo': 919000, 'Cusco': 428000}

# %% [markdown]
# ## Remove "Trujillo"

# %%
population.pop("Trujillo")
population
# Out:
# {'Lima': 10092000, 'Arequipa': 1008000, 'Cusco': 428000}

# %% [markdown]
# ## FINAL DICTIONARIE

# %%
print(population) # tambien podriamos poner solo population
# Out:
# {'Lima': 10092000, 'Arequipa': 1008000, 'Cusco': 428000}
