# %% [markdown]
# # Parte 2 – Tuplas
#
# **Assignment 1 – Fundamentos de Python**
# **Diplomado en Ciencia de Datos – PUCP | Grupo 9**
#
# Una tupla es una colección **ordenada e inmutable**. Se parece a una lista en
# que mantiene el orden y se accede por índice, pero una vez creada su contenido
# no puede cambiarse. Se escribe entre paréntesis `( )`.
#
# > Se sigue el mismo formato que en las otras partes: expresión suelta cuando la
# > celda muestra un solo valor, y un único `print()` con bucle cuando hay varios.

# %% [markdown]
# ## 1. Crear la tupla e imprimirla
#
# Se define `ages` con las cinco edades del enunciado.

# %%
ages = (20, 25, 22, 30, 28)

ages
# Out:
# (20, 25, 22, 30, 28)

# %% [markdown]
# ## 2. Primer y último elemento
#
# Se accede por posición: el índice `0` es el primer elemento y el índice `-1`
# permite llegar al último sin necesidad de conocer el tamaño de la tupla.

# %%
extremos = {
    "Primer elemento": ages[0],
    "Último elemento": ages[-1],
}

for etiqueta, valor in extremos.items():
    print(f"{etiqueta}: {valor}")
# Out:
# Primer elemento: 20
# Último elemento: 28

# %% [markdown]
# ## 3. Valor máximo, mínimo y número de elementos
#
# Aunque una tupla no se puede modificar, sí se puede **leer**, por lo que
# `max()`, `min()` y `len()` funcionan igual que en una lista.

# %%
resumen = {
    "Valor máximo": max(ages),
    "Valor mínimo": min(ages),
    "Número de elementos": len(ages),
}

for etiqueta, valor in resumen.items():
    print(f"{etiqueta}: {valor}")
# Out:
# Valor máximo: 30
# Valor mínimo: 20
# Número de elementos: 5

# %% [markdown]
# ## 4. Intentar modificar un elemento
#
# Se intenta reasignar `ages[0]`. La línea queda comentada para que el notebook
# pueda ejecutarse completo sin detenerse, tal como permite el enunciado.

# %%
# Intento de modificación (produce error si se descomenta):
# ages[0] = 21

# Las tuplas son inmutables: sus elementos no pueden cambiarse
# después de haber creado la tupla.

# %% [markdown]
# ## ¿Por qué Python no permite modificar una tupla?
#
# Las tuplas son **inmutables**: al crearse, Python fija su contenido y el tipo
# `tuple` no implementa la operación de asignación por índice (`__setitem__`).
# Por eso una línea como `ages[0] = 21` lanza:
#
# ```
# TypeError: 'tuple' object does not support item assignment
# ```
#
# Esta inmutabilidad es intencional y resulta útil porque:
#
# - **Protege los datos** que no deberían cambiar durante la ejecución.
# - **Permite usarlas como claves de un diccionario**, ya que su valor no varía
#   (las listas, al ser mutables, no pueden usarse como claves).
#
# Si se necesita un valor distinto, no se modifica la tupla: se crea una nueva,
# por ejemplo `ages = (21,) + ages[1:]`.
